# %% [markdown]
# # Basics of C++
#
# This document summarize everything that is necessary in orden to get up-to date with the basics of the lenguage.

# %% [markdown]
# ## 1
# The first program on c++ is the given above. This programs helps me to learn the basics secuence in c++.
#
#
# ```c++
# #include<iostream>
#
# using namespace std;
#
# int main(){
#
# 	cout<<"Hola mundo :D "<<endl;
#
# 	return 0;
# }
# ```
#
#
# It is necessary to note that:
#
# 1. int main()  función de tipo entero
#
# 2. <<endl es un espacio de línea o usar /n
#
# 3. // is used to make comments.
#
# **This programs does:** print with the tool "cout" the string given in the " ".

# %% [markdown]
# ## 2
# Now, it is important to review some of the types of variables, inners (int), floats (float) and character (char).
#
#
# ```c++
# #include<iostream>
#
# using namespace std;
#
# int main(){
#
# 	//Varibales: Enteros
# 	// Operador de asignación =
# 	int entero =15;
#
# 	cout<<entero<<endl;
#
# 	// Flotante: numeros decimales
# 	float flotante = 15.45;
#
# 	cout<<flotante<<endl;
#
# 	// Double: sirve para asignar numeros más extensos
# 	double doble = 16.4587;
#
# 	cout<<doble<<endl;
#
# 	//Varible de tipo caracter: Char
# 	char letra ='a';
# 	cout<<letra<<endl;
#
#
# 	return 0;
# }
# ```
# Here the importance of define and asigned a value for the created variable.

# %% [markdown]
# ## 25
# Exercise. Write the code for a sum. From 0 to a number "n".
#
# ``` c++
# // 20-01-2025
# // Exercise: Write a program that calculates the value of the following sum: 1+2+3+...+n.
#
#
# #include<iostream> // standar c++ library.
# #include<conio.h>
#
#
#
# using namespace std;
#
# int main(){
# 	int n, suma = 0; // inicialization of the variables.
#
# 	cout<<"Please, write the number of elements for the sum: ";
# 	cin>>n;
#
# 	for(int i= 1; i<=n; i++){
# 		suma = suma + i;
# 	}
#
# 	cout<<"\nLa suma:  "<<suma<<endl;
#
# 	getch();	 // Used to get a value from the user.
# 	return 0;
# }
#
#
# ```

# %% [markdown]
# ## 26
# We've asked for a function that returns the value of the factorial.
#
# ``` c++
# // 26
# // 20-01-2025
#
# //Write a program that calculates the factorial of a number, for example, n! = n*(n-1)*(n-2)*...
#
# #include<iostream>
# #include<conio.h>
# #include<stdlib.h> // here we would like to used the function SYTEM PAUSE.
#
#
# using namespace std;
#
# int main(){
# 	int n, factorial = 1;
#
#
# 	cout<<"Please, write the number that you would like to know the factorial: ";
# 	cin>>n;
#
# 	for(int i=0; i<n  ;i++){
# 		factorial = factorial*(n-i);
# 	}
#
# 	cout<<"\nThe factorial of the number "<<n<<" is "<<factorial<<endl;
#
#
# 	return 0;
# }
# ```

# %% [markdown]
# ## 27
# Now, we need to calculated the sum of the value 2^1 + 2^2 + 2^3 + .....
# ``` c++
# // 27
# // 20-01-2025
#
# //Write a program that calculates the value of 2^1 + 2^2 + 2^3 + .....
#
# // Calculates the sum of the powers of n.
#
#
# #include<iostream>
#
# #include<conio.h>
# #include<stdlib.h> // here we would like to used the function SYTEM PAUSE.
#
# #include <cmath>  // Necesario para pow()
#
#
#
# using namespace std;
#
# int main(){
# 	int n, value =0;
#
# 	cout<<"Please write the value n for the calcualtion ";
# 	cin>>n;
#
# 	for(int i= 1 ; i<=n; i++){
# 		value =  value + pow(2,i);
# 	}
#
# 	cout<<"The value is "<<value<<endl;
#
# return 0;
# }
#
# ```
#
# Finally, here it is importan the use of the library #include<cmath> needed to calculate the power of two.

# %% [markdown]
# ## 28
# We've written a program that calculates the fibonacci series.
# ``` c++
# // 28
# // 20-01-2025
#
# //Write a program that calculates fibonnaci series until wherever you want.
# // 1 1 2 3 5 8 13 ... n
# // z y x
# //   z y
#
# #include<iostream>
#
# #include<conio.h>
#
# #include<cmath>
#
# using namespace std;
#
# int main(){
#
# 	int n,x=0,y=1,z =1;
#
# 	cout<<"Please write the number until you'd like calculate the Fibonacci serie: ";
# 	cin>>n;
#
# 	for(int i = 0; i<n ; i++){
# 		i = i++;
# 		x = z+y;
# 		cout<<x<<" ";
# 		z=y;
# 		y=x;
# 	}
#
# 	cout<<"\nThe position of the Fibonnaci Serie is "<<n<< " and its value is "<<x<<endl;
# 	return 0;
# }
#
# ```
# Here, it is important to notice the replacement of the positions while the cicle for is increasing.
